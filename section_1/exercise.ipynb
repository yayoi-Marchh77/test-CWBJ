# %% [markdown]
# <a href="https://colab.research.google.com/github/yayoi-Marchh77/test-CWBJ/blob/main/section_1/exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 演習
# Pythonを学ぶ前に、Google Colaboratoryの使い方に慣れておきましょう。
# このノートブックで、以下のセルの操作を行ってみましょう。
#
# * コードセルの作成
# * コードセルにPythonのコードを記述し、「Hello World!」と表示
# * コードセルに足し算のコードを記述し、結果を表示
# * テキストセルの作成
# * テキストセルに文章を記述
# * テキストセルで文章を改行
# * テキストセルにリストを記述
# * セルの上下の入れ替え
# * セルの消去

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
a = 3
b = 5
print ( a + b )
# Out:
# 8

# %% [markdown]
# ## ***Pythonの学習再開***
#
# ###　colabに帰ってきたら分かる！分かるよ！
#
#
# 1.   CWBJで学んだからGitHubも怖くない
# 2.   Geminiがいても怖くない
